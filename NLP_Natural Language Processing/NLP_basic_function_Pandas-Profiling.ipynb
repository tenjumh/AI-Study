# %% [markdown]
# # 판다스 프로파일링
# - 좋은 머신러닝 결과를 얻기 위해서는 데이터의 성격을 파악하는 과정 선행이 필요<br>
# - 이 과정에서 데이터 내 값의 분포, 변수 간의 관계, Null 등 결측값 존재 파악 등의 과정이 필요 <br>
# - 이런 과정을 <b>EDA(Exploratory Data Analysis, 탐색적 데이터 분석)</b>라고 한다.<br>
# - .profile_report()라는 명령으로 탐색하는 패키지인 "판다스 프로파일링" 확인해 본다.<br>
# - "pip install -U pandas-profiling"를 설치한다.

# %%
import pandas as pd
import pandas_profiling

# %%
data = pd.read_csv('C:/Users/fxk/PycharmProjects/tenjumh/Study/NLP_Natural Language Processing/spam.csv', encoding='latin1')

# %%
data[:5]   #data의 상위 5개 행 출력
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# - v1은 ham인지 spam인지
# - v2는 본문 내용
# - 이후는 다 NaN : Null값

# %%
#일단 리포트를 저장해 보자
#pr = data.profile_report()
data.profile_report()
# Out:
# C:\Anaconda3\envs\mytest\lib\site-packages\pandas_profiling\model\correlations.py:124: UserWarning: There was an attempt to calculate the cramers correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"cramers": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/pandas-profiling/pandas-profiling/issues
# (include the error message: 'The internally computed table of expected frequencies has a zero element at (0, 1).')
#   correlation_name=correlation_name, error=error
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
# ...
